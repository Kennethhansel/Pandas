# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
df = pd.read_clipboard()
df
# Out:
#                                                                         Waktu  \
# 14:00  -        14:05     5    Opening  /       Sambutan   oleh            MC
# 14:05  -        14:08     3    Doa      Pembuka Diana      Trivena  Yulianti,
# 14:08  -        14:13     5    Sambutan Ketua   Panitia    "Pak           Roi
# (Ketua Panitia  Dean      List Semester Genap   2024/2025) NaN           None
# "      NaN      NaN       NaN  NaN      NaN     NaN        NaN           None
# 14:13  -        14:18     5    Sambutan Dekan   "Pak       Oscar    Karnalim,
# (Dekan Fakultas Teknologi dan  Rekayasa Cerdas) NaN        NaN           None
# "      NaN      NaN       NaN  NaN      NaN     NaN        NaN           None
#
#                                                                      Kegiatan  \
# 14:00  -        14:05     5    Opening  /       Sambutan   oleh           Tim
# 14:05  -        14:08     3    Doa      Pembuka Diana      Trivena    S.Kom.,
# ...
